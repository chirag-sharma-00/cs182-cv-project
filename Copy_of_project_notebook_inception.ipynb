# %% [markdown]
# <a href="https://colab.research.google.com/github/chirag-sharma-00/cs182-cv-project/blob/main/Copy_of_project_notebook_inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import pandas as pd
import glob
import pathlib
import tqdm
import os
import time
import copy
from __future__ import print_function
from __future__ import division
from torchvision import datasets, models, transforms
from torch.utils.data import Dataset
from PIL import Image
from google.colab import drive

# %%
# !rm -rf sample_data

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip drive/MyDrive/tiny-imagenet-200.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_446.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_153.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_295.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_411.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_104.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_387.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_18.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_368.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_407.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_112.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_391.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_450.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_145.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_59.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_283.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_329.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_22.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_352.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_217.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_7.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_169.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_493.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_186.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_305.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_75.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_240.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_485.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_190.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_63.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_313.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_256.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_128.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_344.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_34.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_201.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_276.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_43.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_299.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_333.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_221.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_364.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_14.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_108.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_237.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_372.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_260.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_325.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_55.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_149.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_132.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_427.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_79.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_309.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_96.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_165.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_470.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_80.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_173.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_489.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_466.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_38.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_348.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_124.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_431.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_125.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_430.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_39.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_349.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_172.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_488.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_467.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_81.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_164.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_471.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_78.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_308.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_97.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_133.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_426.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_148.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_261.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_324.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_54.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_236.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_373.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_109.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_220.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_365.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_15.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_277.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_42.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_298.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_332.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_345.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_35.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_200.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_129.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_62.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_312.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_257.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_484.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_191.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_304.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_74.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_241.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_168.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_492.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_187.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_23.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_353.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_216.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_6.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_58.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_282.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_328.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_451.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_144.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_390.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_406.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_113.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_386.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_19.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_369.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_410.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_105.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_294.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_447.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_152.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_270.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_335.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_45.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_159.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_227.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_12.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_362.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_231.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_374.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_118.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_266.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_53.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_323.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_289.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_28.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_358.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_134.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_421.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_90.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_163.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_499.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_476.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_69.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_319.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_86.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_175.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_460.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_122.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_437.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_440.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_155.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_49.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_339.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_293.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_417.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_102.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_381.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_401.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_114.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_397.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_378.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_456.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_143.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_285.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_138.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_354.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_24.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_1.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_211.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_495.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_180.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_73.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_303.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_246.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_179.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_483.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_196.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_315.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_65.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_250.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_32.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_342.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_207.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_33.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_343.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_206.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_314.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_64.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_251.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_178.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_482.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_197.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_72.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_302.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_247.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_494.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_181.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_355.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_25.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_0.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_210.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_139.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_284.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_457.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_142.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_396.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_379.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_400.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_115.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_380.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_416.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_103.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_48.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_338.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_292.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_441.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_154.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_123.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_436.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_174.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_461.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_68.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_318.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_87.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_162.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_498.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_477.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_91.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_135.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_420.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_29.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_359.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_267.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_52.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_322.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_288.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_119.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_230.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_375.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_226.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_13.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_363.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_158.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_271.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_334.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_44.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_435.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_120.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_209.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_462.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_198.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_177.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_84.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_474.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_161.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_248.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_92.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_423.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_136.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_458.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_321.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_51.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_264.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_376.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_399.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_233.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_419.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_360.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_10.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_225.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_47.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_337.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_272.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_205.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_340.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_30.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_439.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_252.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_88.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_67.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_317.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_194.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_481.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_244.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_301.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_71.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_478.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_182.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_497.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_213.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_3.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_26.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_356.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_287.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_268.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_141.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_454.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_395.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_116.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_403.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_383.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_229.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_100.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_415.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_291.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_157.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_442.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_156.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_443.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_290.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_101.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_414.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_382.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_228.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_117.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_402.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_394.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_140.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_455.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_286.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_269.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_212.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_2.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_27.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_357.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_479.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_183.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_496.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_245.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_300.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_70.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_195.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_480.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_253.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_89.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_66.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_316.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_438.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_204.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_341.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_31.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_46.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_336.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_273.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_361.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_11.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_224.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_418.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_377.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_398.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_232.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_320.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_50.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_265.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_459.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_422.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_137.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_249.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_93.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_475.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_160.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_85.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_463.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_199.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_176.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_208.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_434.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_121.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_203.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_36.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_346.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_254.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_311.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_61.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_468.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_192.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_487.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_242.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_98.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_77.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_307.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_184.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_491.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_5.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_215.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_350.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_20.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_429.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_281.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_147.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_452.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_239.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_393.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_110.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_405.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_385.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_106.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_413.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_297.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_278.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_151.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_444.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_433.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_126.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_464.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_171.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_258.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_82.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_472.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_188.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_167.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_94.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_425.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_130.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_219.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_9.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_57.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_327.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_262.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_409.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_370.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_235.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_16.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_366.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_223.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_389.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_448.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_331.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_41.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_274.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_330.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_40.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_275.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_449.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_17.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_367.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_222.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_388.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_371.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_234.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_408.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_56.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_326.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_263.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_218.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_8.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_424.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_131.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_95.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_473.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_189.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_166.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_259.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_83.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_465.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_170.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_432.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_127.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_150.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_445.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_296.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_279.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_107.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_412.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_384.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_111.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_404.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_238.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_392.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_146.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_453.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_280.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_428.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_4.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_214.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_351.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_21.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_185.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_490.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_243.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_99.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_76.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_306.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_469.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_193.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_486.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_255.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_310.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_60.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_202.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_37.JPEG
#   inflating: tiny-imagenet-200/train/n01984695/images/n01984695_347.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_397.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_378.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_73.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_401.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_114.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_285.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_456.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_24.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_143.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_293.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_339.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_32.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_440.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_155.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_381.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_9.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_417.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_65.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_102.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_315.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_250.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_179.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_483.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_196.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_342.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_207.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_49.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_354.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_211.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_138.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_303.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_246.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_495.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_180.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_90.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_118.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_231.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_374.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_28.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_266.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_289.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_323.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_159.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_270.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_335.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_69.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_86.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_5.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_227.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_362.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_175.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_12.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_460.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_319.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_122.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_437.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_45.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_134.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_53.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_421.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_358.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_163.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_499.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_476.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_162.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_498.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_477.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_359.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_135.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_52.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_420.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_123.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_436.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_44.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_318.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_174.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_13.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_461.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_4.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_226.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_363.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_68.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_87.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_271.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_334.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_158.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_267.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_288.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_322.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_29.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_230.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_375.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_91.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_119.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_494.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_181.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_302.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_247.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_139.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_355.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_210.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_48.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_343.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_206.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_178.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_482.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_197.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_314.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_251.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_416.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_64.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_103.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_380.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_8.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_33.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_441.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_154.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_292.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_338.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_457.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_25.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_142.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_284.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_72.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_400.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_115.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_396.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_379.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_79.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_96.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_237.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_372.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_149.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_260.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_325.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_38.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_276.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_333.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_299.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_108.JPEG
#   inflating: tiny-imagenet-200/train/n02963159/images/n02963159_80.JPEG
# ...
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_129.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_200.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_345.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_27.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_216.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_31.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_353.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_187.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_168.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_492.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_241.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_89.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_304.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_66.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_113.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_406.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_390.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_144.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_451.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_282.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_328.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_152.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_447.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_294.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_105.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_410.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_369.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_386.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_368.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_387.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_104.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_411.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_295.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_153.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_446.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_283.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_329.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_145.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_450.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_391.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_112.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_407.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_240.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_88.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_305.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_67.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_186.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_169.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_493.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_217.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_30.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_352.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_201.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_344.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_26.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_128.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_256.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_71.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_313.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_190.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_485.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_108.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_3.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_364.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_221.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_51.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_299.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_333.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_276.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_149.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_325.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_47.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_260.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_10.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_372.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_237.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_470.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_165.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_84.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_309.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_427.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_132.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_431.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_124.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_348.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_466.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_173.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_489.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_92.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_197.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_178.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_482.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_99.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_251.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_76.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_314.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_206.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_343.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_21.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_139.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_210.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_37.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_355.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_181.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_494.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_247.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_302.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_60.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_115.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_400.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_379.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_396.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_142.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_457.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_284.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_154.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_441.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_338.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_292.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_103.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_416.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_8.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_380.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_95.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_318.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_461.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_174.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_436.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_123.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_359.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_420.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_135.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_83.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_477.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_162.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_498.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_17.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_375.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_230.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_119.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_322.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_288.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_40.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_267.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_56.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_334.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_271.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_158.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_363.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_226.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_4.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_5.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_362.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_227.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_159.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_57.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_335.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_270.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_323.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_289.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_41.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_266.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_118.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_16.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_374.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_231.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_476.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_163.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_499.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_82.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_421.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_134.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_358.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_437.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_122.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_460.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_175.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_94.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_319.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_381.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_102.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_417.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_9.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_339.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_293.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_155.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_440.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_285.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_143.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_456.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_378.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_397.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_114.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_401.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_246.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_303.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_61.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_180.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_495.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_211.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_36.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_354.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_138.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_207.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_342.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_20.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_98.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_250.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_77.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_315.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_196.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_179.JPEG
#   inflating: tiny-imagenet-200/train/n03837869/images/n03837869_483.JPEG

# %%
data_dir = pathlib.Path('tiny-imagenet-200/')

# %%
#image_count = len(list(data_dir.glob('**/*.JPEG')))
# !rm tiny-imagenet-200/.DS_Store
# !rm tiny-imagenet-200/train/.DS_Store
# !rm tiny-imagenet-200/val/.DS_Store
# !rm tiny-imagenet-200/test/.DS_Store
# Out:
# rm: cannot remove 'tiny-imagenet-200/train/.DS_Store': No such file or directory
# rm: cannot remove 'tiny-imagenet-200/val/.DS_Store': No such file or directory
# rm: cannot remove 'tiny-imagenet-200/test/.DS_Store': No such file or directory

# %% [markdown]
# ## Preliminary Analysis

# %%
images = pd.read_csv("tiny-imagenet-200/words.txt", names = ['Id', 'labels'], sep = '\t')

# %%
CLASS_NAMES = np.array([item.name for item in (data_dir / 'train').glob('*')])
CLASS_NAMES.sort()
print(len(CLASS_NAMES)) #should be 200
sum([cls in images['Id'].unique() for cls in CLASS_NAMES])
# Out:
# 200
# 200

# %% [markdown]
# ## Create augmented validation data folder

# %%
import data_augmentation as aug
import os

# %%
#os.mkdir("tiny-imagenet-200/val/augmented_images")

prev_annotations = pd.read_csv("tiny-imagenet-200/val/val_annotations.txt", 
                              sep='\t', names=["Filename", "Class", "BB1", 
                                               "BB2", "BB3", "BB4"])
prev_annotations.drop(["BB1", "BB2", "BB3", "BB4"], axis=1, inplace=True)
new_annotations = pd.DataFrame(columns=["Filename", "Class"])

for img_file in os.listdir("tiny-imagenet-200/val/images"):
  path = "tiny-imagenet-200/val/images" + "/" + img_file
  augmented_imgs = aug.augmented_data_from_path(path)
  for i, a in enumerate(augmented_imgs):
    im = Image.fromarray(a)
    prefix = img_file.split(".")[0]
    im.save("tiny-imagenet-200/val/augmented_images/" + prefix + "_" + str(i) + 
            ".JPEG")
    new_annotations = new_annotations.append({"Filename" : prefix + "_" + str(i) + ".JPEG", 
                            "Class" : prev_annotations.loc[
                              prev_annotations["Filename"] == prefix + ".JPEG",
                              "Class"
                            ].item()}, ignore_index=True)
new_annotations.to_csv("tiny-imagenet-200/val/augmented_val_annotations.txt", 
                       sep='\t', index=False, header=False)

# %%
# !zip -r /content/augmented_images.zip /content/tiny-imagenet-200/val/augmented_images/
# Out:
# 	zip warning: name not matched: /content/tiny-imagenet-200/val/augmented_images/
#
# zip error: Nothing to do! (try: zip -r /content/augmented_images.zip . -i /content/tiny-imagenet-200/val/augmented_images/)

# %% [markdown]
# ## Feature extraction/fine tuning model training code

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=1, is_inception=True):
    if torch.cuda.is_available():
      model = model.cuda()
      
    since = time.time()

    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training (no val for now)
        for phase in ['train','val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                # move to gpu
                inputs = inputs.to(device)
                labels.data = labels.data.to(device)
                
                # zero the parameter gradients
                optimizer.zero_grad()
                
                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.

                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
def set_parameter_requires_grad(model, feature_extracting=True):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def predict(dataloaders, model): 
    """
    Run a forward pass (without caching data) for given model and return accuracy
    """
    if torch.cuda.is_available():
      model = model.cuda()

    accuracies = []
    model.eval()
    
    for phase in tqdm.tqdm(['train', 'val']): 
        counter = 0
        running_corrects = 0
        running_total = 0

        for inputs, labels in dataloaders[phase]: 
            inputs = inputs.to(device)
            labels.data = labels.data.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            counter += 1
            
            running_corrects += torch.sum(preds == labels.data)
            running_total += len(preds)
            
        phase_acc = running_corrects / running_total
        print(phase_acc)
        accuracies.append(phase_acc)

    return accuracies

# %%
# Custom dataloader based on https://pytorch.org/tutorials/beginner/basics/data_tutorial.html
class ValidationDataset(Dataset):
  def __init__(self, annotations_file, img_dir, transform=None):
    self.img_labels = pd.read_csv(annotations_file, sep='\t', names=['image', 'label', 'x1', 'y1', 'x2', 'y2'])
    self.img_dir = img_dir
    self.transform = transform

  def __len__(self):
    return len(self.img_labels)

  def __getitem__(self, idx):
    img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
    image = Image.open(img_path)
    image = image.convert('RGB')
    label = self.img_labels.iloc[idx, 1]
    label = np.where(label==CLASS_NAMES)[0][0]
    if self.transform:
        image = self.transform(image)
    return image, label

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Testing Inception v3 out of the box

# %%
data_dir = data_dir
# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "inception_v3"
# Number of classes in the dataset
num_classes = 200
# Batch size for training (change depending on how much memory you have)
batch_size = 8
# Number of epochs to train for
num_epochs = 3
# Flag for feature extracting. When False, we finetune the whole model,
# when True we only update the reshaped layer params
feature_extract = True
CUDA_LAUNCH_BLOCKING=1

# %%
model = torch.hub.load('pytorch/vision:v0.9.0', model_name, pretrained=True)
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.9.0.zip" to /root/.cache/torch/hub/v0.9.0.zip
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(FloatProgress(value=0.0, max=108857766.0), HTML(value='')))

# %%
#change last layers in model to match tiny imagenet
model.AuxLogits.fc = nn.Linear(768, num_classes)
model.fc = nn.Linear(2048, num_classes)

# %%
if torch.cuda.is_available():
  model.cuda()

# %%
#inception expects input size 3*299*299
input_size = 299

# %% [markdown]
# ### Feature extracting model performance on original validation data

# %%
data_transform = transforms.Compose([
        transforms.Resize(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

image_datasets = {
    'train': datasets.ImageFolder(os.path.join(data_dir, 'train'), 
                                  data_transform),
    'val': ValidationDataset(os.path.join(data_dir, 'val', 'val_annotations.txt'), 
                                      os.path.join(data_dir, 'val', 'images'), data_transform),
}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                                   batch_size=batch_size, 
                                                   shuffle=True, num_workers=2) 
                                                   for x in image_datasets.keys()}

# %%
num_classes = 200
input_size = 299

model_fe = models.inception_v3(pretrained=True)
set_parameter_requires_grad(model_fe, feature_extract)
# Handle the auxilary net
num_ftrs = model_fe.AuxLogits.fc.in_features
model_fe.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
# Handle the primary net
num_ftrs = model_fe.fc.in_features
model_fe.fc = nn.Linear(num_ftrs,num_classes)

# %%
# Send the model to GPU
model_fe = model_fe.to(device)

# Gather the parameters to be optimized/updated in this run. We will only update 
# the parameters that we have just initialized, i.e. the parameters with 
# requires_grad is True.
print("Params to learn:")
params_to_update = []
for name, param in model_fe.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 AuxLogits.fc.weight
# 	 AuxLogits.fc.bias
# 	 fc.weight
# 	 fc.bias

# %%
optimizer_fe = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
criterion = nn.CrossEntropyLoss()
# Train and evaluate
model_fe, hist = train_model(model_fe, dataloaders_dict, criterion, 
                             optimizer_fe, num_epochs=num_epochs, 
                             is_inception=True)

# %%
accuracies = predict(dataloaders_dict, model_fe)

# %%
for i, key in enumerate(image_datasets.keys()):
  print(key + " accuracy = ", accuracies[i])

# %%
torch.save(model_fe.state_dict(), 'cs182_project_models/oob-inception.pt')

# %% [markdown]
# ### Feature extracting model performance on augmented validation data

# %%
data_transform = transforms.Compose([
        transforms.Resize(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

image_datasets = {
    'train': datasets.ImageFolder(os.path.join(data_dir, 'train'), 
                                  data_transform),
    'val': ValidationDataset(os.path.join(data_dir, 'val', 'augmented_val_annotations.txt'), 
                                      os.path.join(data_dir, 'val', 'augmented_val_images'), data_transform),
}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                                   batch_size=batch_size, 
                                                   shuffle=True, num_workers=2) 
                                                   for x in image_datasets.keys()}

# %%
accuracies = predict(dataloaders_dict, model_fe)

# %%
for i, key in enumerate(image_datasets.keys()):
  print(key + " accuracy = ", accuracies[i])

# %% [markdown]
# ## Fine-tuning the out of the box Inception v3 model

# %%
data_dir = data_dir
# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "inception_v3"
# Number of classes in the dataset
num_classes = 200
# Batch size for training (change depending on how much memory you have)
batch_size = 32
# Number of epochs to train for
num_epochs = 3
# Flag for feature extracting. When False, we finetune the whole model,
# when True we only update the reshaped layer params
feature_extract = True
CUDA_LAUNCH_BLOCKING=1

# %%
model = torch.hub.load('pytorch/vision:v0.9.0', model_name, pretrained=True)
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.9.0.zip" to /root/.cache/torch/hub/v0.9.0.zip
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(FloatProgress(value=0.0, max=108857766.0), HTML(value='')))

# %%
#change last layers in model to match tiny imagenet
model.AuxLogits.fc = nn.Linear(768, num_classes)
model.fc = nn.Linear(2048, num_classes)

# %%
if torch.cuda.is_available():
  model.cuda()

# %%
#inception expects input size 3*299*299
input_size = 299

# %% [markdown]
# ### Fine-tuned model performance on original validation data

# %%
data_transform = transforms.Compose([
        transforms.Resize(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

image_datasets = {
    'train': datasets.ImageFolder(os.path.join(data_dir, 'train'), 
                                  data_transform),
    'val': ValidationDataset(os.path.join(data_dir, 'val', 'val_annotations.txt'), 
                                      os.path.join(data_dir, 'val', 'images'), data_transform),
}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                                   batch_size=batch_size, 
                                                   shuffle=True, num_workers=2) 
                                                   for x in image_datasets.keys()}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-31e2d6153c05> in <module>()
#       8     'train': datasets.ImageFolder(os.path.join(data_dir, 'train'),
#       9                                   data_transform),
# ---> 10     'val': ValidationDataset(os.path.join(data_dir, 'val', 'val_annotations.txt'),
#      11                                       os.path.join(data_dir, 'val', 'images'), data_transform),
#      12 }
#
# NameError: name 'ValidationDataset' is not defined

# %%
num_classes = 200
input_size = 299

model_fe = models.inception_v3(pretrained=True)
set_parameter_requires_grad(model_fe, not feature_extract)
# Handle the auxilary net
num_ftrs = model_fe.AuxLogits.fc.in_features
model_fe.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
# Handle the primary net
num_ftrs = model_fe.fc.in_features
model_fe.fc = nn.Linear(num_ftrs,num_classes)

# %%
# Send the model to GPU
model_fe = model_fe.to(device)

# Gather the parameters to be optimized/updated in this run. We will only update 
# the parameters that we have just initialized, i.e. the parameters with 
# requires_grad is True.
print("Params to learn:")
params_to_update = []
for name, param in model_fe.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)

# %%
optimizer_fe = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
criterion = nn.CrossEntropyLoss()
# Train and evaluate
model_fe, hist = train_model(model_fe, dataloaders_dict, criterion, 
                             optimizer_fe, num_epochs=num_epochs, 
                             is_inception=True)
# Out:
# Epoch 0/2
# ----------
# train Loss: 3.3031 Acc: 0.5644
# val Loss: 0.9213 Acc: 0.7682
#
# Epoch 1/2
# ----------
# train Loss: 1.3897 Acc: 0.7857
# val Loss: 0.8355 Acc: 0.7884
#
# Epoch 2/2
# ----------
# train Loss: 0.9278 Acc: 0.8555
# val Loss: 0.8725 Acc: 0.7807
#
# Training complete in 45m 4s
# Best val Acc: 0.788400

# %%
accuracies = predict(dataloaders_dict, model_fe)
# Out:
#  50%|█████     | 1/2 [05:11<05:11, 311.14s/it]
# tensor(0.8961, device='cuda:0')
# 100%|██████████| 2/2 [05:42<00:00, 171.38s/it]
# tensor(0.7884, device='cuda:0')

# %%
for i, key in enumerate(image_datasets.keys()):
  print(key + " accuracy = ", accuracies[i])
# Out:
# train accuracy =  tensor(0.8961, device='cuda:0')
# val accuracy =  tensor(0.7884, device='cuda:0')

# %%
torch.save(model_fe.state_dict(), '/content/drive/MyDrive/cs182_project_models/fine-tuned-inception.pt')

# %% [markdown]
# ### Fine-tuned model performance on augmented validation data

# %%
data_transform = transforms.Compose([
        transforms.Resize(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

image_datasets = {
    'train': datasets.ImageFolder(os.path.join(data_dir, 'train'), 
                                  data_transform),
    'val': ValidationDataset(os.path.join(data_dir, 'val', 'augmented_val_annotations.txt'), 
                                      os.path.join(data_dir, 'val', 'augmented_val_images'), data_transform),
}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                                   batch_size=batch_size, 
                                                   shuffle=True, num_workers=2) 
                                                   for x in image_datasets.keys()}

# %%
accuracies = predict(dataloaders_dict, model_fe)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [05:08<05:08, 308.68s/it]
# tensor(0.8961, device='cuda:0')
# 100%|██████████| 2/2 [05:40<00:00, 170.02s/it]
# tensor(0.6098, device='cuda:0')

# %%
for i, key in enumerate(image_datasets.keys()):
  print(key + " accuracy = ", accuracies[i])
# Out:
# train accuracy =  tensor(0.8961, device='cuda:0')
# val accuracy =  tensor(0.6098, device='cuda:0')

# %% [markdown]
# ##Adversarial training

# %%
#load finetuned model
model.load_state_dict(torch.load('drive/MyDrive/cs182_project_models/fine-tuned-augmented-train-inception.pt'))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b7a3a3f5f5fb> in <module>()
#       1 #load finetuned model
# ----> 2 model.load_state_dict(torch.load('drive/MyDrive/cs182_project_models/fine-tuned-augmented-train-inception.pt'))
#       3 model.eval()
#
# NameError: name 'model' is not defined

# %%
# !pip install torchattacks

# %%
import torchattacks
atks = [torchattacks.FGSM(model, eps=8/255),
        torchattacks.PGD(model, eps=8/255, alpha=2/255, steps=7),
        torchattacks.Square(model, eps=8/255),
       ]

# %%
def train_model_adv(model, dataloaders, criterion, optimizer, num_epochs=3, is_inception=True):
    """
    Takes a pretrained model and trains it using a unique adversarial attack for each epoch
    """
    if torch.cuda.is_available():
      model = model.cuda()
      
    since = time.time()
    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        atk = atks[epoch]

        for phase in ['train','val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                # move to gpu
                inputs = inputs.to(device)
                #adv attack
                inputs = atk(inputs, labels)

                labels.data = labels.data.to(device)
                
                # zero the parameter gradients
                optimizer.zero_grad()
                
                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.

                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)

                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
criterion = nn.CrossEntropyLoss()
optimizer_fe = optim.SGD(params_to_update, lr=0.001, momentum=0.9)

# %%
model_adv, hist = train_model_adv(model_fe, dataloaders_dict, criterion, 
                             optimizer_fe, num_epochs=3, 
                             is_inception=True)

# %% [markdown]
# ###Test on Imagenet-a, Imagenet-o data

# %%
# !unzip drive/MyDrive/182-cv-project/data/imagenet-a.zip
imagenet_a_path = pathlib.Path('imagenet-a/')
# !unzip drive/MyDrive/182-cv-project/data/imagenet-o.zip
imagenet_o_path = pathlib.Path('imagenet-o/')

# %%
class AdversarialDataset(Dataset):
  def __init__(self, annotations_file, img_dir, transform=None):
    self.img_labels = pd.read_csv(annotations_file, sep='\t', names=['image', 'label', 'x1', 'y1', 'x2', 'y2'])
    self.img_dir = img_dir
    self.transform = transform

  def __len__(self):
    return len(self.img_labels)

  def __getitem__(self, idx):
    img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
    image = Image.open(img_path)
    image = image.convert('RGB')
    label = self.img_labels.iloc[idx, 1]
    label = np.where(label==CLASS_NAMES)[0][0]
    if self.transform:
        image = self.transform(image)
    return image, label

# %% [markdown]
# ##Adversarial training with stability objective

# %%
# !pip install torchattacks
# Out:
# Requirement already satisfied: torchattacks in /usr/local/lib/python3.7/dist-packages (2.14.2)

# %%
data_dir = data_dir
# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "inception_v3"
# Number of classes in the dataset
num_classes = 200
# Batch size for training (change depending on how much memory you have)
batch_size = 32
# Number of epochs to train for
num_epochs = 3
# Flag for feature extracting. When False, we finetune the whole model,
# when True we only update the reshaped layer params
feature_extract = True
CUDA_LAUNCH_BLOCKING=1

# %%
model = torch.hub.load('pytorch/vision:v0.9.0', model_name, pretrained=True)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.9.0

# %%
#change last layers in model to match tiny imagenet
model.AuxLogits.fc = nn.Linear(768, num_classes)
model.fc = nn.Linear(2048, num_classes)

# %%
if torch.cuda.is_available():
  model.cuda()

# %%
#load finetuned model
model.load_state_dict(torch.load('drive/MyDrive/chet_models/fine-tuned-augmented-train-inception.pt'))
model.eval()
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=200, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=200, bias=True)
# )

# %%
num_classes = 200
input_size = 299

model_fe = model
set_parameter_requires_grad(model_fe, not feature_extract)
# Handle the auxilary net
num_ftrs = model_fe.AuxLogits.fc.in_features
model_fe.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
# Handle the primary net
num_ftrs = model_fe.fc.in_features
model_fe.fc = nn.Linear(num_ftrs,num_classes)

# %%
# Send the model to GPU
model_fe = model_fe.to(device)

# Gather the parameters to be optimized/updated in this run. We will only update 
# the parameters that we have just initialized, i.e. the parameters with 
# requires_grad is True.
print("Params to learn:")
params_to_update = []
for name, param in model_fe.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 Conv2d_1a_3x3.conv.weight
# 	 Conv2d_1a_3x3.bn.weight
# 	 Conv2d_1a_3x3.bn.bias
# 	 Conv2d_2a_3x3.conv.weight
# 	 Conv2d_2a_3x3.bn.weight
# 	 Conv2d_2a_3x3.bn.bias
# 	 Conv2d_2b_3x3.conv.weight
# 	 Conv2d_2b_3x3.bn.weight
# 	 Conv2d_2b_3x3.bn.bias
# 	 Conv2d_3b_1x1.conv.weight
# 	 Conv2d_3b_1x1.bn.weight
# 	 Conv2d_3b_1x1.bn.bias
# 	 Conv2d_4a_3x3.conv.weight
# 	 Conv2d_4a_3x3.bn.weight
# 	 Conv2d_4a_3x3.bn.bias
# 	 Mixed_5b.branch1x1.conv.weight
# 	 Mixed_5b.branch1x1.bn.weight
# 	 Mixed_5b.branch1x1.bn.bias
# 	 Mixed_5b.branch5x5_1.conv.weight
# 	 Mixed_5b.branch5x5_1.bn.weight
# 	 Mixed_5b.branch5x5_1.bn.bias
# 	 Mixed_5b.branch5x5_2.conv.weight
# 	 Mixed_5b.branch5x5_2.bn.weight
# 	 Mixed_5b.branch5x5_2.bn.bias
# 	 Mixed_5b.branch3x3dbl_1.conv.weight
# 	 Mixed_5b.branch3x3dbl_1.bn.weight
# 	 Mixed_5b.branch3x3dbl_1.bn.bias
# 	 Mixed_5b.branch3x3dbl_2.conv.weight
# 	 Mixed_5b.branch3x3dbl_2.bn.weight
# 	 Mixed_5b.branch3x3dbl_2.bn.bias
# 	 Mixed_5b.branch3x3dbl_3.conv.weight
# 	 Mixed_5b.branch3x3dbl_3.bn.weight
# 	 Mixed_5b.branch3x3dbl_3.bn.bias
# 	 Mixed_5b.branch_pool.conv.weight
# 	 Mixed_5b.branch_pool.bn.weight
# 	 Mixed_5b.branch_pool.bn.bias
# 	 Mixed_5c.branch1x1.conv.weight
# 	 Mixed_5c.branch1x1.bn.weight
# 	 Mixed_5c.branch1x1.bn.bias
# 	 Mixed_5c.branch5x5_1.conv.weight
# 	 Mixed_5c.branch5x5_1.bn.weight
# 	 Mixed_5c.branch5x5_1.bn.bias
# 	 Mixed_5c.branch5x5_2.conv.weight
# 	 Mixed_5c.branch5x5_2.bn.weight
# 	 Mixed_5c.branch5x5_2.bn.bias
# 	 Mixed_5c.branch3x3dbl_1.conv.weight
# 	 Mixed_5c.branch3x3dbl_1.bn.weight
# 	 Mixed_5c.branch3x3dbl_1.bn.bias
# 	 Mixed_5c.branch3x3dbl_2.conv.weight
# 	 Mixed_5c.branch3x3dbl_2.bn.weight
# 	 Mixed_5c.branch3x3dbl_2.bn.bias
# 	 Mixed_5c.branch3x3dbl_3.conv.weight
# 	 Mixed_5c.branch3x3dbl_3.bn.weight
# 	 Mixed_5c.branch3x3dbl_3.bn.bias
# 	 Mixed_5c.branch_pool.conv.weight
# 	 Mixed_5c.branch_pool.bn.weight
# 	 Mixed_5c.branch_pool.bn.bias
# 	 Mixed_5d.branch1x1.conv.weight
# 	 Mixed_5d.branch1x1.bn.weight
# 	 Mixed_5d.branch1x1.bn.bias
# 	 Mixed_5d.branch5x5_1.conv.weight
# 	 Mixed_5d.branch5x5_1.bn.weight
# 	 Mixed_5d.branch5x5_1.bn.bias
# 	 Mixed_5d.branch5x5_2.conv.weight
# 	 Mixed_5d.branch5x5_2.bn.weight
# 	 Mixed_5d.branch5x5_2.bn.bias
# 	 Mixed_5d.branch3x3dbl_1.conv.weight
# 	 Mixed_5d.branch3x3dbl_1.bn.weight
# 	 Mixed_5d.branch3x3dbl_1.bn.bias
# 	 Mixed_5d.branch3x3dbl_2.conv.weight
# 	 Mixed_5d.branch3x3dbl_2.bn.weight
# 	 Mixed_5d.branch3x3dbl_2.bn.bias
# 	 Mixed_5d.branch3x3dbl_3.conv.weight
# 	 Mixed_5d.branch3x3dbl_3.bn.weight
# 	 Mixed_5d.branch3x3dbl_3.bn.bias
# 	 Mixed_5d.branch_pool.conv.weight
# 	 Mixed_5d.branch_pool.bn.weight
# 	 Mixed_5d.branch_pool.bn.bias
# 	 Mixed_6a.branch3x3.conv.weight
# 	 Mixed_6a.branch3x3.bn.weight
# 	 Mixed_6a.branch3x3.bn.bias
# 	 Mixed_6a.branch3x3dbl_1.conv.weight
# 	 Mixed_6a.branch3x3dbl_1.bn.weight
# 	 Mixed_6a.branch3x3dbl_1.bn.bias
# 	 Mixed_6a.branch3x3dbl_2.conv.weight
# 	 Mixed_6a.branch3x3dbl_2.bn.weight
# 	 Mixed_6a.branch3x3dbl_2.bn.bias
# 	 Mixed_6a.branch3x3dbl_3.conv.weight
# 	 Mixed_6a.branch3x3dbl_3.bn.weight
# 	 Mixed_6a.branch3x3dbl_3.bn.bias
# 	 Mixed_6b.branch1x1.conv.weight
# 	 Mixed_6b.branch1x1.bn.weight
# 	 Mixed_6b.branch1x1.bn.bias
# 	 Mixed_6b.branch7x7_1.conv.weight
# 	 Mixed_6b.branch7x7_1.bn.weight
# 	 Mixed_6b.branch7x7_1.bn.bias
# 	 Mixed_6b.branch7x7_2.conv.weight
# 	 Mixed_6b.branch7x7_2.bn.weight
# 	 Mixed_6b.branch7x7_2.bn.bias
# 	 Mixed_6b.branch7x7_3.conv.weight
# 	 Mixed_6b.branch7x7_3.bn.weight
# 	 Mixed_6b.branch7x7_3.bn.bias
# 	 Mixed_6b.branch7x7dbl_1.conv.weight
# 	 Mixed_6b.branch7x7dbl_1.bn.weight
# 	 Mixed_6b.branch7x7dbl_1.bn.bias
# 	 Mixed_6b.branch7x7dbl_2.conv.weight
# 	 Mixed_6b.branch7x7dbl_2.bn.weight
# 	 Mixed_6b.branch7x7dbl_2.bn.bias
# 	 Mixed_6b.branch7x7dbl_3.conv.weight
# 	 Mixed_6b.branch7x7dbl_3.bn.weight
# 	 Mixed_6b.branch7x7dbl_3.bn.bias
# 	 Mixed_6b.branch7x7dbl_4.conv.weight
# 	 Mixed_6b.branch7x7dbl_4.bn.weight
# 	 Mixed_6b.branch7x7dbl_4.bn.bias
# 	 Mixed_6b.branch7x7dbl_5.conv.weight
# 	 Mixed_6b.branch7x7dbl_5.bn.weight
# 	 Mixed_6b.branch7x7dbl_5.bn.bias
# 	 Mixed_6b.branch_pool.conv.weight
# 	 Mixed_6b.branch_pool.bn.weight
# 	 Mixed_6b.branch_pool.bn.bias
# 	 Mixed_6c.branch1x1.conv.weight
# 	 Mixed_6c.branch1x1.bn.weight
# 	 Mixed_6c.branch1x1.bn.bias
# 	 Mixed_6c.branch7x7_1.conv.weight
# 	 Mixed_6c.branch7x7_1.bn.weight
# 	 Mixed_6c.branch7x7_1.bn.bias
# 	 Mixed_6c.branch7x7_2.conv.weight
# 	 Mixed_6c.branch7x7_2.bn.weight
# 	 Mixed_6c.branch7x7_2.bn.bias
# 	 Mixed_6c.branch7x7_3.conv.weight
# 	 Mixed_6c.branch7x7_3.bn.weight
# 	 Mixed_6c.branch7x7_3.bn.bias
# 	 Mixed_6c.branch7x7dbl_1.conv.weight
# 	 Mixed_6c.branch7x7dbl_1.bn.weight
# 	 Mixed_6c.branch7x7dbl_1.bn.bias
# 	 Mixed_6c.branch7x7dbl_2.conv.weight
# 	 Mixed_6c.branch7x7dbl_2.bn.weight
# 	 Mixed_6c.branch7x7dbl_2.bn.bias
# 	 Mixed_6c.branch7x7dbl_3.conv.weight
# 	 Mixed_6c.branch7x7dbl_3.bn.weight
# 	 Mixed_6c.branch7x7dbl_3.bn.bias
# 	 Mixed_6c.branch7x7dbl_4.conv.weight
# 	 Mixed_6c.branch7x7dbl_4.bn.weight
# 	 Mixed_6c.branch7x7dbl_4.bn.bias
# 	 Mixed_6c.branch7x7dbl_5.conv.weight
# 	 Mixed_6c.branch7x7dbl_5.bn.weight
# 	 Mixed_6c.branch7x7dbl_5.bn.bias
# 	 Mixed_6c.branch_pool.conv.weight
# 	 Mixed_6c.branch_pool.bn.weight
# 	 Mixed_6c.branch_pool.bn.bias
# 	 Mixed_6d.branch1x1.conv.weight
# 	 Mixed_6d.branch1x1.bn.weight
# 	 Mixed_6d.branch1x1.bn.bias
# 	 Mixed_6d.branch7x7_1.conv.weight
# 	 Mixed_6d.branch7x7_1.bn.weight
# 	 Mixed_6d.branch7x7_1.bn.bias
# 	 Mixed_6d.branch7x7_2.conv.weight
# 	 Mixed_6d.branch7x7_2.bn.weight
# 	 Mixed_6d.branch7x7_2.bn.bias
# 	 Mixed_6d.branch7x7_3.conv.weight
# 	 Mixed_6d.branch7x7_3.bn.weight
# 	 Mixed_6d.branch7x7_3.bn.bias
# 	 Mixed_6d.branch7x7dbl_1.conv.weight
# 	 Mixed_6d.branch7x7dbl_1.bn.weight
# 	 Mixed_6d.branch7x7dbl_1.bn.bias
# 	 Mixed_6d.branch7x7dbl_2.conv.weight
# 	 Mixed_6d.branch7x7dbl_2.bn.weight
# 	 Mixed_6d.branch7x7dbl_2.bn.bias
# 	 Mixed_6d.branch7x7dbl_3.conv.weight
# 	 Mixed_6d.branch7x7dbl_3.bn.weight
# 	 Mixed_6d.branch7x7dbl_3.bn.bias
# 	 Mixed_6d.branch7x7dbl_4.conv.weight
# 	 Mixed_6d.branch7x7dbl_4.bn.weight
# 	 Mixed_6d.branch7x7dbl_4.bn.bias
# 	 Mixed_6d.branch7x7dbl_5.conv.weight
# 	 Mixed_6d.branch7x7dbl_5.bn.weight
# 	 Mixed_6d.branch7x7dbl_5.bn.bias
# 	 Mixed_6d.branch_pool.conv.weight
# 	 Mixed_6d.branch_pool.bn.weight
# 	 Mixed_6d.branch_pool.bn.bias
# 	 Mixed_6e.branch1x1.conv.weight
# 	 Mixed_6e.branch1x1.bn.weight
# 	 Mixed_6e.branch1x1.bn.bias
# 	 Mixed_6e.branch7x7_1.conv.weight
# 	 Mixed_6e.branch7x7_1.bn.weight
# 	 Mixed_6e.branch7x7_1.bn.bias
# 	 Mixed_6e.branch7x7_2.conv.weight
# 	 Mixed_6e.branch7x7_2.bn.weight
# 	 Mixed_6e.branch7x7_2.bn.bias
# 	 Mixed_6e.branch7x7_3.conv.weight
# 	 Mixed_6e.branch7x7_3.bn.weight
# 	 Mixed_6e.branch7x7_3.bn.bias
# 	 Mixed_6e.branch7x7dbl_1.conv.weight
# 	 Mixed_6e.branch7x7dbl_1.bn.weight
# 	 Mixed_6e.branch7x7dbl_1.bn.bias
# 	 Mixed_6e.branch7x7dbl_2.conv.weight
# 	 Mixed_6e.branch7x7dbl_2.bn.weight
# 	 Mixed_6e.branch7x7dbl_2.bn.bias
# 	 Mixed_6e.branch7x7dbl_3.conv.weight
# 	 Mixed_6e.branch7x7dbl_3.bn.weight
# 	 Mixed_6e.branch7x7dbl_3.bn.bias
# 	 Mixed_6e.branch7x7dbl_4.conv.weight
# 	 Mixed_6e.branch7x7dbl_4.bn.weight
# 	 Mixed_6e.branch7x7dbl_4.bn.bias
# 	 Mixed_6e.branch7x7dbl_5.conv.weight
# 	 Mixed_6e.branch7x7dbl_5.bn.weight
# 	 Mixed_6e.branch7x7dbl_5.bn.bias
# 	 Mixed_6e.branch_pool.conv.weight
# 	 Mixed_6e.branch_pool.bn.weight
# 	 Mixed_6e.branch_pool.bn.bias
# 	 AuxLogits.conv0.conv.weight
# 	 AuxLogits.conv0.bn.weight
# 	 AuxLogits.conv0.bn.bias
# 	 AuxLogits.conv1.conv.weight
# 	 AuxLogits.conv1.bn.weight
# 	 AuxLogits.conv1.bn.bias
# 	 AuxLogits.fc.weight
# 	 AuxLogits.fc.bias
# 	 Mixed_7a.branch3x3_1.conv.weight
# 	 Mixed_7a.branch3x3_1.bn.weight
# 	 Mixed_7a.branch3x3_1.bn.bias
# 	 Mixed_7a.branch3x3_2.conv.weight
# 	 Mixed_7a.branch3x3_2.bn.weight
# 	 Mixed_7a.branch3x3_2.bn.bias
# 	 Mixed_7a.branch7x7x3_1.conv.weight
# 	 Mixed_7a.branch7x7x3_1.bn.weight
# 	 Mixed_7a.branch7x7x3_1.bn.bias
# 	 Mixed_7a.branch7x7x3_2.conv.weight
# 	 Mixed_7a.branch7x7x3_2.bn.weight
# 	 Mixed_7a.branch7x7x3_2.bn.bias
# 	 Mixed_7a.branch7x7x3_3.conv.weight
# 	 Mixed_7a.branch7x7x3_3.bn.weight
# 	 Mixed_7a.branch7x7x3_3.bn.bias
# 	 Mixed_7a.branch7x7x3_4.conv.weight
# 	 Mixed_7a.branch7x7x3_4.bn.weight
# 	 Mixed_7a.branch7x7x3_4.bn.bias
# 	 Mixed_7b.branch1x1.conv.weight
# 	 Mixed_7b.branch1x1.bn.weight
# 	 Mixed_7b.branch1x1.bn.bias
# 	 Mixed_7b.branch3x3_1.conv.weight
# 	 Mixed_7b.branch3x3_1.bn.weight
# 	 Mixed_7b.branch3x3_1.bn.bias
# 	 Mixed_7b.branch3x3_2a.conv.weight
# 	 Mixed_7b.branch3x3_2a.bn.weight
# 	 Mixed_7b.branch3x3_2a.bn.bias
# 	 Mixed_7b.branch3x3_2b.conv.weight
# 	 Mixed_7b.branch3x3_2b.bn.weight
# 	 Mixed_7b.branch3x3_2b.bn.bias
# 	 Mixed_7b.branch3x3dbl_1.conv.weight
# 	 Mixed_7b.branch3x3dbl_1.bn.weight
# 	 Mixed_7b.branch3x3dbl_1.bn.bias
# 	 Mixed_7b.branch3x3dbl_2.conv.weight
# 	 Mixed_7b.branch3x3dbl_2.bn.weight
# 	 Mixed_7b.branch3x3dbl_2.bn.bias
# 	 Mixed_7b.branch3x3dbl_3a.conv.weight
# 	 Mixed_7b.branch3x3dbl_3a.bn.weight
# 	 Mixed_7b.branch3x3dbl_3a.bn.bias
# 	 Mixed_7b.branch3x3dbl_3b.conv.weight
# 	 Mixed_7b.branch3x3dbl_3b.bn.weight
# 	 Mixed_7b.branch3x3dbl_3b.bn.bias
# 	 Mixed_7b.branch_pool.conv.weight
# 	 Mixed_7b.branch_pool.bn.weight
# 	 Mixed_7b.branch_pool.bn.bias
# 	 Mixed_7c.branch1x1.conv.weight
# 	 Mixed_7c.branch1x1.bn.weight
# 	 Mixed_7c.branch1x1.bn.bias
# 	 Mixed_7c.branch3x3_1.conv.weight
# 	 Mixed_7c.branch3x3_1.bn.weight
# 	 Mixed_7c.branch3x3_1.bn.bias
# 	 Mixed_7c.branch3x3_2a.conv.weight
# 	 Mixed_7c.branch3x3_2a.bn.weight
# 	 Mixed_7c.branch3x3_2a.bn.bias
# 	 Mixed_7c.branch3x3_2b.conv.weight
# 	 Mixed_7c.branch3x3_2b.bn.weight
# 	 Mixed_7c.branch3x3_2b.bn.bias
# 	 Mixed_7c.branch3x3dbl_1.conv.weight
# 	 Mixed_7c.branch3x3dbl_1.bn.weight
# 	 Mixed_7c.branch3x3dbl_1.bn.bias
# 	 Mixed_7c.branch3x3dbl_2.conv.weight
# 	 Mixed_7c.branch3x3dbl_2.bn.weight
# 	 Mixed_7c.branch3x3dbl_2.bn.bias
# 	 Mixed_7c.branch3x3dbl_3a.conv.weight
# 	 Mixed_7c.branch3x3dbl_3a.bn.weight
# 	 Mixed_7c.branch3x3dbl_3a.bn.bias
# 	 Mixed_7c.branch3x3dbl_3b.conv.weight
# 	 Mixed_7c.branch3x3dbl_3b.bn.weight
# 	 Mixed_7c.branch3x3dbl_3b.bn.bias
# 	 Mixed_7c.branch_pool.conv.weight
# 	 Mixed_7c.branch_pool.bn.weight
# 	 Mixed_7c.branch_pool.bn.bias
# 	 fc.weight
# 	 fc.bias

# %%
import torchattacks
atks = [torchattacks.FGSM(model, eps=8/255),
        torchattacks.PGD(model, eps=8/255, alpha=2/255, steps=7),
       ]

# %%
def train_model_adv(model, dataloaders, criterion, optimizer, num_epochs=3, 
                    is_inception=True, stability_param=0.1):
    """
    Takes a pretrained model and trains it using a unique adversarial attack for each epoch
    """
    if torch.cuda.is_available():
      model = model.cuda()
      
    since = time.time()
    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        atk = np.random.choice(atks)

        for phase in ['train','val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                # move to gpu
                inputs = inputs.to(device)
                #adv attack
                adv_inputs = atk(inputs, labels)

                labels.data = labels.data.to(device)
                
                # zero the parameter gradients
                optimizer.zero_grad()
                
                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.

                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)

                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss_0 = loss1 + 0.4*loss2

                        adv_outputs, adv_aux_outputs = model(adv_inputs)
                        outputs = nn.LogSoftmax(dim=1)(outputs)
                        adv_outputs = nn.LogSoftmax(dim=1)(adv_outputs)
                        aux_outputs = nn.LogSoftmax(dim=1)(aux_outputs)
                        adv_aux_outputs = nn.LogSoftmax(dim=1)(adv_aux_outputs)

                        stability_loss = nn.KLDivLoss(log_target=True)
                        loss1 = stability_loss(outputs, adv_outputs)
                        loss2 = stability_loss(aux_outputs, adv_aux_outputs)
                        loss_s = loss1 + 0.4*loss2

                        loss = loss_0 + stability_param * loss_s
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
criterion = nn.CrossEntropyLoss()
optimizer_fe = optim.SGD(params_to_update, lr=0.001, momentum=0.9)

# %%
data_transform = transforms.Compose([
        transforms.Resize(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

image_datasets = {
    'train': datasets.ImageFolder(os.path.join(data_dir, 'train'), 
                                  data_transform),
    'val': ValidationDataset(os.path.join(data_dir, 'val', 'augmented_val_annotations.txt'), 
                                      os.path.join(data_dir, 'val', 'augmented_val_images'), data_transform),
}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                                   batch_size=batch_size, 
                                                   shuffle=True, num_workers=2) 
                                                   for x in image_datasets.keys()}

# %%
model_adv, hist = train_model_adv(model_fe, dataloaders_dict, criterion, 
                             optimizer_fe, num_epochs=3, 
                             is_inception=True)
# Out:
# Epoch 0/2
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2611: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# train Loss: 2.2110 Acc: 0.7418
# val Loss: 2.5617 Acc: 0.4690
# Epoch 1/2
# ----------
# train Loss: 0.9877 Acc: 0.8552
# val Loss: 3.1767 Acc: 0.3944
# Epoch 2/2
# ----------
# train Loss: 0.6753 Acc: 0.8991
# val Loss: 3.0035 Acc: 0.4322
# Training complete in 127m 24s
# Best val Acc: 0.469000

# %%
accuracies = predict(dataloaders_dict, model_fe)
# Out:
#  50%|█████     | 1/2 [05:17<05:17, 317.20s/it]
# tensor(0.6888, device='cuda:0')
# 100%|██████████| 2/2 [05:49<00:00, 174.80s/it]
# tensor(0.4690, device='cuda:0')

# %%
for i, key in enumerate(image_datasets.keys()):
  print(key + " accuracy = ", accuracies[i])
# Out:
# train accuracy =  tensor(0.6888, device='cuda:0')
# val accuracy =  tensor(0.4690, device='cuda:0')

# %%
torch.save(model_fe.state_dict(), '/content/drive/MyDrive/chet_models/fine-tuned-inception-adv-training-with-stability.pt')

# %% [markdown]
# ###Test on Imagenet-a, Imagenet-o data

# %%
# !unzip drive/MyDrive/182-cv-project/data/imagenet-a.zip
imagenet_a_path = pathlib.Path('imagenet-a/')
# !unzip drive/MyDrive/182-cv-project/data/imagenet-o.zip
imagenet_o_path = pathlib.Path('imagenet-o/')

# %%
class AdversarialDataset(Dataset):
  def __init__(self, annotations_file, img_dir, transform=None):
    self.img_labels = pd.read_csv(annotations_file, sep='\t', names=['image', 'label', 'x1', 'y1', 'x2', 'y2'])
    self.img_dir = img_dir
    self.transform = transform

  def __len__(self):
    return len(self.img_labels)

  def __getitem__(self, idx):
    img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
    image = Image.open(img_path)
    image = image.convert('RGB')
    label = self.img_labels.iloc[idx, 1]
    label = np.where(label==CLASS_NAMES)[0][0]
    if self.transform:
        image = self.transform(image)
    return image, label
